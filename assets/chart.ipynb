# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# df = pd.read_csv("./data/anime_movie.csv",usecols=['Tên Phim', 'Nội Dung', 'Thể Loại', 'Rating'])
df = pd.read_csv("./data/anime_movie.csv")
df.head()
# Out:
#                                             Tên Phim  \
# 0  Saigo ni Hitotsu dake Onegai shitemo Yoroshii ...
# 1                Boku no Hero Academia: Final Season
# 2                       Pokémon Horizons: The Series
# 3  Kao ni Denai Kashiwada-san to Kao ni Deru Oota...
# 4                        Kekkon Yubiwa Monogatari II
#
#                                             Tên Khác  \
# 0  Tôi Có Thể Thỉnh Cầu Một Điều Cuối Cùng Không?...
# 1  My Hero Academia Final Season, My Hero Academia 8
# 2   Pokemon (Shinsaku Anime), Pocket Monsters (2023)
# 3  Inexpressive Kashiwada and Expressive Oota, Ex...
# 4  Tales of Wedding Rings Season 2 | Câu Chuyện N...
#
#                                             Nội Dung  \
# 0  Tôi Có Thể Thỉnh Cầu Một Điều Cuối Cùng Không?...
# 1        Phần cuối của bộ phim Boku no Hero Academia
# 2  Tạm biệt Satoshi (Ask Ketchum) và Một Series m...
# 3  Kashiwada-san, một nữ sinh trung học mặt đơ vớ...
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Rating'].dropna(), bins=20, kde=True, color='skyblue')
plt.title('Phân Bố Điểm Số Anime')
plt.xlabel('Điểm số (Score)')
plt.ylabel('Số lượng phim')
plt.show()

# %%
plt.figure(figsize=(12, 6))
df_filtered = df[(df['Năm Phát Hành'] >= 1980) & (df['Năm Phát Hành'] <= 2025)].copy()
year_counts = df_filtered['Năm Phát Hành'].value_counts().sort_index()

sns.lineplot(x=year_counts.index, y=year_counts.values, marker='o', color='#e74c3c', linewidth=2)
plt.title('Số Lượng Anime Phát Hành (1980 - 2025)', fontsize=14)
plt.xlabel('Năm', fontsize=12)
plt.ylabel('Số lượng', fontsize=12)
plt.xlim(1980, 2025) # Cố định trục X
plt.show()

# %%
plt.figure(figsize=(12, 8))
genres_exploded = df['Thể Loại'].dropna().str.split(',').explode().str.strip()
top_genres = genres_exploded.value_counts().head(10)

sns.barplot(x=top_genres.values, y=top_genres.index, palette='viridis')
plt.title('Top 10 Thể Loại Anime Phổ Biến Nhất', fontsize=15)
plt.xlabel('Số lượng phim', fontsize=12)
plt.ylabel('Thể loại', fontsize=12)
plt.show()
# Out:
# C:\Users\tungl\AppData\Local\Temp\ipykernel_4664\730271813.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_genres.values, y=top_genres.index, palette='viridis')
